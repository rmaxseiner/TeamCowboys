# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import datetime as dt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
#from sklearn.metrics import mean_squared_error, r2_score
#from sklearn.gaussian_process import GaussianProcessRegressor
#from sklearn import linear_model
#from sklearn.linear_model import Ridge
#from sklearn.linear_model import ElasticNet
pd.set_option('display.max_columns', 100)
import warnings
warnings.filterwarnings('ignore')

# %%
by_city = pd.read_csv('~/GlobalLandTemperaturesByCity.csv').astype({'dt':'datetime64','AverageTemperature':'float32', \
                                    'AverageTemperatureUncertainty':'float32'}).rename(columns={'dt':'Date'})                                    
by_city['Year']= by_city['Date'].dt.year
by_city['Month']= by_city['Date'].dt.month
by_city = by_city.astype({'Year':'int32','Month':'int32'})
by_city.head(3)
# Out:
#         Date  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0 1743-11-01               6.068                          1.737  Århus
# 1 1743-12-01                 NaN                            NaN  Århus
# 2 1744-01-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude  Year  Month
# 0  Denmark   57.05N    10.33E  1743     11
# 1  Denmark   57.05N    10.33E  1743     12
# 2  Denmark   57.05N    10.33E  1744      1

# %%
by_country = pd.read_csv('~/GlobalLandTemperaturesByCountry.csv').astype({'dt':'datetime64','AverageTemperature':'float32', \
                                    'AverageTemperatureUncertainty':'float32'}).rename(columns={'dt':'Date'})
                                    
by_country['Year']= by_country['Date'].dt.year
by_country['Month']= by_country['Date'].dt.month
by_country = by_country.astype({'Year':'int32','Month':'int32'})
by_country.head(3)
# Out:
#         Date  AverageTemperature  AverageTemperatureUncertainty Country  Year  \
# 0 1743-11-01               4.384                          2.294   Åland  1743
# 1 1743-12-01                 NaN                            NaN   Åland  1743
# 2 1744-01-01                 NaN                            NaN   Åland  1744
#
#    Month
# 0     11
# 1     12
# 2      1

# %%
globaltemp_df = pd.read_csv("~/GlobalTemperatures.csv").astype({'dt':'datetime64'}).rename(columns={'dt':'Date'})
globaltemp_df['Year']= globaltemp_df['Date'].dt.year
globaltemp_df['Month']= globaltemp_df['Date'].dt.month
globaltemp_df.head(3)
# Out:
#         Date  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0 1750-01-01                   3.034                              3.574
# 1 1750-02-01                   3.083                              3.702
# 2 1750-03-01                   5.626                              3.076
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
#
#    LandAndOceanAverageTemperatureUncertainty  Year  Month
# 0                                        NaN  1750      1
# 1                                        NaN  1750      2
# 2                                        NaN  1750      3

# %%
df_fuel = pd.read_csv("~/annual-change-fossil-fuels-coal-gas-oil.csv")
df_fuel.rename(columns = {'Entity':'Country', 'Fossil.fuels..TWh.growth...sub.method.':'FossilFuelGrowth', 
                      'Coal..TWh.growth...sub.method.':'CoalGrowth', 'Gas..TWh.growth...sub.method.':'GasGrowth',
                     'Oil..TWh.growth...sub.method.':'OilGrowth'}, inplace = True)
df_fuel.head(3)
# Out:
#   Code  Year               Country  FossilFuelGrowth  CoalGrowth  GasGrowth  \
# 0  ARE  1977  United Arab Emirates            19.441       0.000     14.040
# 1  ARE  1978  United Arab Emirates             7.680       0.000      6.143
# 2  ARE  2006  United Arab Emirates            36.862       1.584     12.773
#
#    OilGrowth region    sub.region
# 0      5.401   Asia  Western Asia
# 1      1.537   Asia  Western Asia
# 2     22.506   Asia  Western Asia

# %%
natural_resources = pd.read_csv("~/natural-resources.csv").rename(columns={'Entity':'Country'})
natural_resources = natural_resources[["Year","Country","Population","Gas consumption","Coal consumption","Oil consumption"]]
natural_resources.head(3)
# Out:
#    Year      Country  Population  Gas consumption  Coal consumption  \
# 0  1980  Afghanistan  13360000.0       56640000.0          119000.0
# 1  1981  Afghanistan  13170000.0       84960000.0          125000.0
# 2  1982  Afghanistan  12880000.0      141600000.0          145000.0
#
#    Oil consumption
# 0         406500.0
# 1         464600.0
# 2         452900.0

# %%
df_fuel = df_fuel.merge(by_country,on=["Country","Year"]).reset_index().merge(natural_resources,on=['Year','Country'])
df_fuel.head(3)
# Out:
#    index Code  Year               Country  FossilFuelGrowth  CoalGrowth  \
# 0      0  ARE  1977  United Arab Emirates            19.441         0.0
# 1      1  ARE  1977  United Arab Emirates            19.441         0.0
# 2      2  ARE  1977  United Arab Emirates            19.441         0.0
#
#    GasGrowth  OilGrowth region    sub.region       Date  AverageTemperature  \
# 0      14.04      5.401   Asia  Western Asia 1977-01-01              17.583
# 1      14.04      5.401   Asia  Western Asia 1977-02-01              20.843
# 2      14.04      5.401   Asia  Western Asia 1977-03-01              26.038
#
#    AverageTemperatureUncertainty  Month  Population  Gas consumption  \
# 0                          0.445      1    735300.0              NaN
# 1                          0.535      2    735300.0              NaN
# 2                          0.662      3    735300.0              NaN
#
#    Coal consumption  Oil consumption
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN

# %%
df = df_fuel.drop('index',axis=1)[["Year","Country","Code","Population","Date","Month", \
                                   "Gas consumption","Coal consumption","Oil consumption","FossilFuelGrowth","CoalGrowth", \
                                  "GasGrowth","OilGrowth","region","AverageTemperature","AverageTemperatureUncertainty"]]
df = df.merge(by_country,on=['Year','Month','Country','AverageTemperature','AverageTemperatureUncertainty']).dropna().groupby(['Year','Country']).mean().drop("Month",axis=1).reset_index()
df.head(5)
# Out:
#    Year     Country  Population  Gas consumption  Coal consumption  \
# 0  1980     Algeria  19220000.0     1.303000e+10           92870.0
# 1  1980   Argentina  27900000.0     1.017000e+10         1360000.0
# 2  1980   Australia  14590000.0     9.119000e+09        67360000.0
# 3  1980     Austria   7610000.0     5.268000e+09         6148000.0
# 4  1980  Bangladesh  79640000.0     1.416000e+09           23500.0
#
#    Oil consumption  FossilFuelGrowth  CoalGrowth  GasGrowth  OilGrowth  \
# 0        7026000.0            28.703      -0.093     27.913      0.884
# 1       30850000.0           -11.909      -1.357      9.239    -19.790
# 2       34520000.0             7.890       9.222     14.291    -15.622
# 3       13480000.0            -4.339       1.149     -1.966     -3.521
# 4        1858000.0             4.123       0.363      1.582      2.179
#
#    AverageTemperature  AverageTemperatureUncertainty
# 0           23.160166                       0.382917
# 1           15.226917                       0.171250
# 2           22.586166                       0.171833
# 3            5.633584                       0.242250
# 4           25.340668                       0.281667

# %%
model_df = pd.DataFrame()
for country in df.Country.unique():
    mydf = df.query("Country == '"+country+"'")
    mydf['TempMinus1'] = mydf.shift(1)['AverageTemperature']
    mydf['TempMinus2'] = mydf.shift(2)['AverageTemperature']
    mydf['TempMinus5'] = mydf.shift(5)['AverageTemperature']
    model_df = pd.concat([model_df,mydf])
model_df
# Out:
#       Year   Country  Population  Gas consumption  Coal consumption  \
# 0     1980   Algeria  19220000.0     1.303000e+10           92870.0
# 62    1981   Algeria  19820000.0     9.799000e+09          279100.0
# 124   1982   Algeria  20450000.0     1.566000e+10          746000.0
# 186   1983   Algeria  21100000.0     1.858000e+10         1210000.0
# 248   1984   Algeria  21760000.0     1.926000e+10         1247000.0
# ...    ...       ...         ...              ...               ...
# 2093  2009  Slovakia   5401000.0     5.398000e+09         7593000.0
# 2169  2010  Slovakia   5404000.0     6.100000e+09         7214000.0
# 2245  2011  Slovakia   5409000.0     5.631000e+09         7209000.0
# 2321  2012  Slovakia   5415000.0     5.290000e+09         6893000.0
# 2397  2013  Slovakia   5422000.0     5.511000e+09         6647000.0
#
#       Oil consumption  FossilFuelGrowth  CoalGrowth  GasGrowth  OilGrowth  \
# 0           7026000.0            28.703      -0.093     27.913      0.884
# 62          7375000.0            37.721      -0.221     32.821      5.121
# 124         8304000.0            32.592       9.188     19.154      4.250
# 186         7898000.0            23.576      -1.047     15.304      9.319
# 248         8710000.0           -11.412       0.942    -21.464      9.110
# ...               ...               ...         ...        ...        ...
# 2093        4677000.0           -12.596      -1.211     -8.617     -2.768
# 2169        4855000.0             9.081       0.243      6.757      2.080
# 2245        4818000.0            -8.171      -2.329     -4.296     -1.547
# 2321        4417000.0            -8.020      -2.417     -3.160     -2.442
# 2397        4485000.0             2.052      -0.240      2.241      0.051
#
#       AverageTemperature  AverageTemperatureUncertainty  TempMinus1  \
# 0              23.160166                       0.382917         NaN
# 62             23.579250                       0.359833   23.160166
# 124            23.094168                       0.342417   23.579250
# 186            23.683001                       0.333000   23.094168
# 248            23.063084                       0.373667   23.683001
# ...                  ...                            ...         ...
# 2093            9.001667                       0.287833    9.397417
# 2169            8.073000                       0.274000    9.001667
# 2245            8.846000                       0.321583    8.073000
# 2321            8.873167                       0.390667    8.846000
# 2397            9.685625                       0.387125    8.873167
#
#       TempMinus2  TempMinus5
# 0            NaN         NaN
# 62           NaN         NaN
# 124    23.160166         NaN
# 186    23.579250         NaN
# 248    23.094168         NaN
# ...          ...         ...
# 2093    9.478917    8.145583
# 2169    9.397417    7.936917
# 2245    9.001667    8.528334
# 2321    8.073000    9.478917
# 2397    8.846000    9.397417
#
# [2416 rows x 15 columns]

# %%
model_df.to_csv("YearlyByCountry.csv")

# %%
by_country.groupby('Year').mean()['AverageTemperature'].plot()
plt.title('Yearly Average Temperatures')
plt.show()

# %%
by_country.groupby('Year').mean()['AverageTemperatureUncertainty'].plot()
plt.title('Yearly Average Temperature Uncertainty')
plt.show()

# %%
globaltemp_df.groupby('Year').mean()['LandAverageTemperature'].plot()
plt.title('Average Land Temperature by Year')
plt.show()

# %%
globaltemp_df.query('Year >= 1973').groupby('Year').mean()['LandAverageTemperature'].plot()
plt.title('Average Land Temperature by Year')
plt.show()

# %%
data_columns = ['Year',
 'Population',
 'Gas consumption',
 'Coal consumption',
 'Oil consumption',
 'FossilFuelGrowth',
 'CoalGrowth',
 'GasGrowth',
 'OilGrowth',
 'AverageTemperature',
 'TempMinus1',
 'TempMinus2',
 'TempMinus5']

# %%
f = plt.figure()
f.set_figwidth(15)
f.set_figheight(15)
ax = sns.heatmap(model_df[data_columns].corr(), annot=True)

# %%
data_columns = ['Year',
 'Population',
 'Gas consumption',
 'Coal consumption',
 'Oil consumption',
 'FossilFuelGrowth',
 'CoalGrowth',
 'GasGrowth',
 'OilGrowth',
 'AverageTemperature']
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(20)
g = sns.pairplot(model_df[data_columns])

# %%
model_df
# Out:
#       Year   Country  Population  Gas consumption  Coal consumption  \
# 0     1980   Algeria  19220000.0     1.303000e+10           92870.0
# 62    1981   Algeria  19820000.0     9.799000e+09          279100.0
# 124   1982   Algeria  20450000.0     1.566000e+10          746000.0
# 186   1983   Algeria  21100000.0     1.858000e+10         1210000.0
# 248   1984   Algeria  21760000.0     1.926000e+10         1247000.0
# ...    ...       ...         ...              ...               ...
# 2093  2009  Slovakia   5401000.0     5.398000e+09         7593000.0
# 2169  2010  Slovakia   5404000.0     6.100000e+09         7214000.0
# 2245  2011  Slovakia   5409000.0     5.631000e+09         7209000.0
# 2321  2012  Slovakia   5415000.0     5.290000e+09         6893000.0
# 2397  2013  Slovakia   5422000.0     5.511000e+09         6647000.0
#
#       Oil consumption  FossilFuelGrowth  CoalGrowth  GasGrowth  OilGrowth  \
# 0           7026000.0            28.703      -0.093     27.913      0.884
# 62          7375000.0            37.721      -0.221     32.821      5.121
# 124         8304000.0            32.592       9.188     19.154      4.250
# 186         7898000.0            23.576      -1.047     15.304      9.319
# 248         8710000.0           -11.412       0.942    -21.464      9.110
# ...               ...               ...         ...        ...        ...
# 2093        4677000.0           -12.596      -1.211     -8.617     -2.768
# 2169        4855000.0             9.081       0.243      6.757      2.080
# 2245        4818000.0            -8.171      -2.329     -4.296     -1.547
# 2321        4417000.0            -8.020      -2.417     -3.160     -2.442
# 2397        4485000.0             2.052      -0.240      2.241      0.051
#
#       AverageTemperature  AverageTemperatureUncertainty  TempMinus1  \
# 0              23.160166                       0.382917         NaN
# 62             23.579250                       0.359833   23.160166
# 124            23.094168                       0.342417   23.579250
# 186            23.683001                       0.333000   23.094168
# 248            23.063084                       0.373667   23.683001
# ...                  ...                            ...         ...
# 2093            9.001667                       0.287833    9.397417
# 2169            8.073000                       0.274000    9.001667
# 2245            8.846000                       0.321583    8.073000
# 2321            8.873167                       0.390667    8.846000
# 2397            9.685625                       0.387125    8.873167
#
#       TempMinus2  TempMinus5
# 0            NaN         NaN
# 62           NaN         NaN
# 124    23.160166         NaN
# 186    23.579250         NaN
# 248    23.094168         NaN
# ...          ...         ...
# 2093    9.478917    8.145583
# 2169    9.397417    7.936917
# 2245    9.001667    8.528334
# 2321    8.073000    9.478917
# 2397    8.846000    9.397417
#
# [2416 rows x 15 columns]

# %%
yearly_avg = model_df.set_index("Year").groupby("Year").mean()
yearly_avg['Gas consumption'] = model_df.groupby(['Year','Country'])['Gas consumption'].mean().groupby('Year').sum()
yearly_avg['Coal consumption'] = model_df.groupby(['Year','Country'])['Coal consumption'].mean().groupby('Year').sum()
yearly_avg['Oil consumption'] = model_df.groupby(['Year','Country'])['Oil consumption'].mean().groupby('Year').sum()
yearly_avg['FossilFuelGrowth'] = model_df.groupby(['Year','Country'])['FossilFuelGrowth'].mean().groupby('Year').sum()
yearly_avg['CoalGrowth'] = model_df.groupby(['Year','Country'])['CoalGrowth'].mean().groupby('Year').sum()
yearly_avg['GasGrowth'] = model_df.groupby(['Year','Country'])['GasGrowth'].mean().groupby('Year').sum()
yearly_avg['OilGrowth'] = model_df.groupby(['Year','Country'])['OilGrowth'].mean().groupby('Year').sum()
yearly_avg['Population'] = model_df.groupby(['Year','Country'])['Population'].mean().groupby('Year').sum()
yearly_avg['log_Gas'] = np.log(yearly_avg['Gas consumption'])
yearly_avg['log_Coal'] = np.log(yearly_avg['Coal consumption'])
yearly_avg['log_Oil'] = np.log(yearly_avg['Oil consumption'])
yearly_avg = yearly_avg
global_temps = globaltemp_df.groupby('Year').mean().reset_index().query("Year >= 1973").drop("Month",axis=1)
yearly_avg = yearly_avg.merge(global_temps,on="Year")
yearly_avg['TempMinus1'] = yearly_avg.shift(1)['AverageTemperature']
yearly_avg['TempMinus2'] = yearly_avg.shift(2)['AverageTemperature']
yearly_avg['TempMinus5'] = yearly_avg.shift(5)['AverageTemperature']
yearly_avg
# Out:
#     Year    Population  Gas consumption  Coal consumption  Oil consumption  \
# 0   1980  3.520742e+09     1.019004e+12      2.315429e+09     2.803656e+09
# 1   1981  3.583076e+09     1.007001e+12      2.364802e+09     2.693236e+09
# 2   1982  3.646517e+09     9.846384e+11      2.432822e+09     2.615005e+09
# 3   1983  3.710594e+09     9.717523e+11      2.541397e+09     2.584809e+09
# 4   1984  3.777334e+09     1.057065e+12      2.702477e+09     2.648520e+09
# 5   1985  3.846210e+09     1.073513e+12      2.864156e+09     2.653958e+09
# 6   1986  3.916121e+09     1.064809e+12      2.912023e+09     2.743547e+09
# 7   1987  3.988083e+09     1.117415e+12      3.057346e+09     2.816492e+09
# 8   1988  4.060976e+09     1.166109e+12      3.183592e+09     2.927792e+09
# 9   1989  4.131563e+09     1.233739e+12      3.218606e+09     3.002605e+09
# 10  1990  4.200977e+09     1.240325e+12      3.199233e+09     3.050523e+09
# 11  1991  4.346404e+09     1.366019e+12      3.588275e+09     3.231985e+09
# 12  1992  4.683994e+09     2.073445e+12      4.134134e+09     3.725955e+09
# 13  1993  4.751564e+09     2.136247e+12      4.154657e+09     3.722057e+09
# 14  1994  4.812299e+09     2.129221e+12      4.192215e+09     3.801157e+09
# 15  1995  4.873092e+09     2.183895e+12      4.304571e+09     3.875198e+09
# 16  1996  4.933433e+09     2.229984e+12      4.397396e+09     3.991828e+09
# 17  1997  4.993099e+09     2.235532e+12      4.327901e+09     4.056029e+09
# 18  1998  5.051628e+09     2.248265e+12      4.308378e+09     4.099392e+09
# 19  1999  5.110805e+09     2.308788e+12      4.336480e+09     4.192458e+09
# 20  2000  5.168914e+09     2.397643e+12      4.553036e+09     4.262541e+09
# 21  2001  5.224751e+09     2.401179e+12      4.620818e+09     4.292982e+09
# 22  2002  5.280484e+09     2.509842e+12      4.740016e+09     4.340406e+09
# 23  2003  5.337154e+09     2.575515e+12      5.127173e+09     4.428660e+09
# 24  2004  5.393134e+09     2.648937e+12      5.572997e+09     4.606192e+09
# 25  2005  5.449196e+09     2.718143e+12      5.944837e+09     4.663918e+09
# 26  2006  5.503821e+09     2.807988e+12      6.281123e+09     4.726676e+09
# 15                                   0.060417
# 16                                   0.059500
# 17                                   0.059167
# 18                                   0.063000
# 19                                   0.063333
# 20                                   0.063500
# 21                                   0.064583
# 22                                   0.062917
# 23                                   0.064333
# 24                                   0.061250
# 25                                   0.060833
# 26                                   0.061000
# 27                                   0.059083
# 28                                   0.057250
# 29                                   0.058917
# 30                                   0.058583
# 31                                   0.059000
# 32                                   0.061500
# 33                                   0.064667

# %%
yearly_avg.to_csv("GlobalYearly.csv")

# %% [markdown]
# ## End of Baseline

# %%
import pandas as pd
from neuralprophet import NeuralProphet
from matplotlib import pyplot as plt

plt.plot(yearly_avg['Year'], yearly_avg['AverageTemperature'])
plt.show()

# %%
new_column = yearly_avg[['Year', 'AverageTemperature']] 
new_column.dropna(inplace=True)
new_column.columns = ['ds', 'y'] 
new_column.tail()
# Out:
#       ds          y
# 29  2009  15.336614
# 30  2010  15.289953
# 31  2011  15.255487
# 32  2012  15.247377
# 33  2013  15.906935

# %%
m = NeuralProphet()
model = m.fit(new_column, freq = 'Y')
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency YS corresponds to 97.059% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - Y
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling weekly seasonality. Run NeuralProphet with weekly_seasonality=True to override this.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 1000
#   0%|          | 0/103 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.23E-01, min: 7.63E-07
#   0%|          | 0/103 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 1.23E-01, min: 1.50E-04
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 1.15E-01
# Epoch[1000/1000]: 100%|██████████| 1000/1000 [00:04<00:00, 227.70it/s, SmoothL1Loss=0.00592, MAE=0.144, RMSE=0.191, RegLoss=0]

# %%
future = n.make_future_dataframe(new_column, periods=81)
forecast = n.predict(future)
forecast.tail()
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency N corresponds to 97.059% of the data.
# WARNING - (NP.df_utils._infer_frequency) - Defined frequency Y is different than major frequency N
# INFO - (NP.df_utils._infer_frequency) - Major frequency Y corresponds to 98.765% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - Y
# INFO - (NP.df_utils._infer_frequency) - Major frequency Y corresponds to 98.765% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - Y
#                               ds     y      yhat1 residual1      trend  \
# 76 2046-12-31 00:00:00.000002013  None  16.730522       NaN  14.168983
# 77 2047-12-31 00:00:00.000002013  None  16.723532       NaN  14.211151
# 78 2048-12-31 00:00:00.000002013  None  16.912476       NaN  14.253435
# 79 2049-12-31 00:00:00.000002013  None  16.906036       NaN  14.295604
# 80 2050-12-31 00:00:00.000002013  None  16.899311       NaN  14.337771
#
#     season_yearly
# 76       2.561540
# 77       2.512381
# 78       2.659040
# 79       2.610434
# 80       2.561540

# %%
fig_forecast = m.plot(forecast)
fig_components = m.plot_components(forecast)
fig_model = m.plot_parameters()

# %%
X = yearly_avg[['Population', 'Gas consumption', 'Coal consumption', 'Oil consumption']]
y = yearly_avg['AverageTemperature']
        
reg = linear_model.LinearRegression()
reg.fit(X, y)
        
print(reg.coef_)
# Out:
# [ 9.59404052e-11 -3.34152225e-12  7.05954180e-10  1.34069948e-09]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
print(model.score(X_train, y_train))

print(model.score(X_test, y_test))
# Out:
# 0.7263923380677619
# 0.9048907362138319

# %%
from sklearn.ensemble import GradientBoostingRegressor
model2 = GradientBoostingRegressor(random_state=0).fit(X_train, y_train)
print('GradientBoosting')
print(model2.score(X_train, y_train))
print(model.score(X_test, y_test))
print('-----------------')


from sklearn.ensemble import RandomForestRegressor
model3 = RandomForestRegressor(random_state=0).fit(X_train, y_train)
model3.score(X_train, y_train)
model3.score(X_test, y_test)
0.8325867908704008
